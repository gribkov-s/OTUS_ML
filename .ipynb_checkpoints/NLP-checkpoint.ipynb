# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys

from tqdm import tqdm_notebook
from fake_useragent import UserAgent

import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ПАРСИНГ

# %%
def get_soup(page_link):
    response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
    soup = BeautifulSoup(response.content, "html.parser")
    return soup

# %%
mail_link = 'https://habr.com/ru&page={}'
soup = get_soup(mail_link.format(1))

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width,initial-scale=1,user-scalable=no" name="viewport"/>
# <title>Хабр</title>
# <link href="https://dr.habracdn.net/habr/5fad4d26/styles/services.bundle.css" media="all" rel="stylesheet"/>
# <script src="https://dr.habracdn.net/habr/5fad4d26/javascripts/libs/jquery-1.8.3.min.js"></script>
# <script>
#   window.create_callback_for_blocked = function(key) {
#     return function() {
#       googletag.cmd.push(function () {
#         googletag.display(key);
#       });
#     }
#   }
#
#   window.habr_blockers_checker = new function() {
#     var result;
#     var callbacksQueue = [];
#     var calledOnce = false;
#
#     function fireCallbacks() {
#       callbacksQueue.forEach(function(callback) {
#         callback(result);
#       });
#       callbacksQueue = [];
#     }
#
#     this.detect = function(imgUrl, callback) {
# ...

# %%
item = soup.find('div', attrs={'post__body post__body_crop'})
#item_name = item.find('h2', attrs={'class':'news-card__title'}).text.strip()
#item_link = item.find_parent('span').attrs['href']

# %%
item

# %%
item_link
# Out:
# 'RuNews24.ru'

# %%
def get_item_links(page_number):
    soup = get_soup(mail_link.format(page_number))
    items = soup.findAll('div', attrs={'class':'v2-listing-card__info'})
    item_links = [item.find_parent('a').attrs['href'] for item in items]
    return item_links

# %%
item_links = []

for page_number in tqdm_notebook(range(1, 10)):
    item_links.extend(get_item_links(page_number))

# %%
item_soup = get_soup(item_links[10])

# %%
def get_item_info(item_soup):
    item_name = item_soup.find('h1').text.strip()
    item_price = item_soup.find('p', attrs={'class':'wt-text-title-03 wt-mr-xs-2'}).text.strip()
    item_sales = item_soup.find('span', attrs={'class':'wt-text-caption-01'}).text
    return {'name':item_name, "price":item_price, "sales":item_sales}

# %%
get_item_info(item_soup)

# %%
data = pd.DataFrame(columns=['name', 'price', 'sales'])

for item_link in tqdm_notebook(item_links[:20]):
    item_soup = get_soup(item_link)
    data_row = get_item_info(item_soup)
    data = data.append(data_row, ignore_index=True)
